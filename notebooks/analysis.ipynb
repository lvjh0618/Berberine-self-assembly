# %%
# Analysis of Berberine Self-Assembly by MD Simulation
## Research Question
How do berberine molecules self-assemble in aqueous solution?
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Object `solution` not found.
